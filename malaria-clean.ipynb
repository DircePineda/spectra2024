# %%
# 1) LOAD & PREPROCESS DATA
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load dataset
data = pd.read_csv("/kaggle/input/malariaclean/malaria.csv")

# Find indices where Raman shift is repeated
split_indices = np.where(data['Wavelength'] == 1705.003906)[0]

# Create a list to store each spectrum
spectra = []

# Create a copy of DataFrame before iteration process
data_copy = data.copy()

# Iterate through split indices to separate spectra
for i in range(len(split_indices)):
    if i == 0:
        spectrum = data_copy.iloc[:split_indices[i]].copy()
    else:
        spectrum = data_copy.iloc[split_indices[i-1]:split_indices[i]].copy()
    # Reset index of spectrum DataFrame
    spectrum.reset_index(drop=True, inplace=True)
     
    # Add 'Spectrum_ID' column
    spectrum['Spectrum_ID'] = i + 1
    
    # Append spectrum to list
    spectra.append(spectrum)
    
# Concatenate all spectra DataFrames into one (ignoring index to preserve column names)
all_spectra_id = pd.concat(spectra, ignore_index=True)

# Save to a single file
all_spectra_id.to_csv("all_spectra_id.csv", index=False)

# Check columns of DataFrame
print(all_spectra_id.columns)
print(spectrum.columns)

# Plot
plt.figure(figsize=(16, 10), dpi=150)

for spectrum_id in all_spectra_id['Spectrum_ID'].unique():
    spectrum_data = all_spectra_id[all_spectra_id['Spectrum_ID'] == spectrum_id]
    plt.plot(spectrum_data['Wavelength'], spectrum_data['Intensity'], label=f'Spectrum {spectrum_id}')

plt.xlabel('Wavelength')
plt.ylabel('Intensity')
plt.title('Raw Spectra')
plt.grid(True)
plt.show()
# Out:
# Index(['Wavelength', 'Intensity', 'Spectrum_ID'], dtype='object')
# Index(['Wavelength', 'Intensity', 'Spectrum_ID'], dtype='object')

# %%
# 2) BASELINE CORRECTION
import numpy as np
import pandas as pd
from scipy.optimize import curve_fit
import matplotlib.pyplot as plt

# Define baseline correction function
def raman_baseline_correction(wavenumbers, spectrum, polynomial_order):
    def chebyshev_polynomial(x, *coefficients):
        return np.polynomial.chebyshev.chebval(x, coefficients)

    # Fit Chebyshev polynomial to entire spectrum
    baseline_coefficients, _ = curve_fit(chebyshev_polynomial, wavenumbers, spectrum, p0=np.zeros(polynomial_order + 1))

    # Subtract fitted polynomial from original spectrum
    corrected_baseline = spectrum - chebyshev_polynomial(wavenumbers, *baseline_coefficients)

    return baseline_coefficients, corrected_baseline 

# Load data
df = pd.read_csv('all_spectra_id.csv')

# Initialize an empty list to store DataFrames
dfs = []

# Initialize a counter for generating unique IDs
id_counter = 1

# Perform baseline correction & append to list
for Spectrum_ID in df['Spectrum_ID'].unique():
    # Extract relevant data for current spectrum
    wavenumbers_spectrum = df[df['Spectrum_ID'] == Spectrum_ID]['Wavelength']
    intensity_spectrum = df[df['Spectrum_ID'] == Spectrum_ID]['Intensity']
    
    # Check if data is not empty
    if wavenumbers_spectrum.empty or intensity_spectrum.empty:
        print(f"No data found for spectrum ID: {Spectrum_ID}")
        continue

    # Perform baseline correction for current spectrum
    polynomial_order_spectrum = 5
    baseline_coefficients_spectrum, corrected_baseline_spectrum = raman_baseline_correction(wavenumbers_spectrum, intensity_spectrum, polynomial_order_spectrum)

    # Generate a unique ID for each spectrum
    spectrum_id = f'Spectrum_{id_counter}'
    id_counter += 1

    # Add Spectrum_ID column back to corrected DataFrame
    corrected_baseline_df = pd.DataFrame({'Spectrum_ID': spectrum_id, 'Wavelength': wavenumbers_spectrum, 'Corrected_Intensity': corrected_baseline_spectrum})
    
    # Reorganize columns
    corrected_baseline_df = corrected_baseline_df[['Spectrum_ID', 'Wavelength', 'Corrected_Intensity']]

    # Append corrected spectrum DataFrame to the list
    dfs.append(corrected_baseline_df)

# Concatenate all DataFrames into a single
combined_df = pd.concat(dfs, ignore_index=True)

# Save combined DataFrame in one file
combined_df.to_csv("combined_file.csv", index=False)

# Print first few rows
print(combined_df.head())

# Plot
plt.figure(figsize=(16, 10), dpi=100)

num_spectra_to_plot = 135 
for spectrum_id in combined_df['Spectrum_ID'].unique()[:num_spectra_to_plot]:
    # Extract data for current spectrum
    spectrum_data = combined_df[combined_df['Spectrum_ID'] == spectrum_id]
    wavenumbers = spectrum_data['Wavelength']
    corrected_intensity = spectrum_data['Corrected_Intensity']
    plt.plot(wavenumbers, corrected_intensity, label=f'Spectrum {spectrum_id}')

plt.xlabel('Wavelength')
plt.ylabel('Corrected Intensity')
plt.title('Spectral Baseline Correction')
plt.show()
# Out:
#   Spectrum_ID   Wavelength  Corrected_Intensity
# 0  Spectrum_1  1705.003906             1.007219
# 1  Spectrum_1  1703.941406           -11.469430
# 2  Spectrum_1  1702.878906             1.931192
# 3  Spectrum_1  1701.816406            -1.132275
# 4  Spectrum_1  1700.753906             2.869620

# %%
# 3) COSMIC RAYS REMOVAL
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Read file
combined_file_path = '/kaggle/working/combined_file.csv'
combined_data = pd.read_csv(combined_file_path)

# 1. Data Loading: verify the file is loaded correctly
print("Loaded combined data:")
print(combined_data.head())

# 2. Data Inspection: verify the structure of loaded data
print("\nData information:")
print(combined_data.info())

# 3. Check enumeration of ID column
print("\nUnique Spectrum_IDs:")
print(combined_data['Spectrum_ID'].unique())

# Define number of spectra
num_spectra = 135

# Initialize a list to store cleaned spectra
cleaned_spectra = []

# 4. Review loop logic
for i in range(num_spectra):
    spectrum_id = f'Spectrum_{i + 1}'
    spectrum_data = combined_data[combined_data['Spectrum_ID'] == spectrum_id]
    
    # 5. Error Handling: check for empty data
    if not spectrum_data.empty:
        try:
            # CLEANING PROCESS
            # A) IDENTIFY COSMIC RAYS POINTS:
            # Calculate second difference of spectrum to accentuate sharp spikes
            first_difference = np.diff(spectrum_data['Corrected_Intensity'], n=1)
            second_difference = np.diff(first_difference, n=1)

            # Estimate threshold for rays detection (proportional to Standard Deviation)
            threshold = - 2 * np.std(second_difference)

            # Identify points where the second difference exceeds the threshold
            cosmic_ray_indices = np.where(second_difference < threshold)[0]

            # B) DETERMINE RANGE OF VALUES:
            # Define start & end values for the window
            for index in cosmic_ray_indices:
                xs = index
                xe = index

                while xs > 0 and second_difference[xs - 1] > 0:
                    xs -= 1

                while xe < len(second_difference) - 1 and second_difference[xe + 1] > 0:
                    xe += 1

            # C) INTERPOLATION:
            # Extract x & y values for interpolation
            x_values = spectrum_data['Wavelength'].values
            y_values = spectrum_data['Corrected_Intensity'].values

            # Adjust x & y values to interpolate within the determined window
            x_values = np.arange(xs, xe + 1)
            y_values = spectrum_data['Corrected_Intensity'].iloc[xs:xe + 1].values

            # Perform polynomial interpolation
            degree = 1
            coefficients = np.polyfit(x_values, y_values, degree)
            interpolated_values = np.polyval(coefficients, x_values)

            # D) REPLACE COSMIC RAY POINTS:
            window_start = max(0, xs)
            window_end = min(len(spectrum_data), xe)

            # Copy original Corrected_Intensity
            cleaned_intensity = spectrum_data['Corrected_Intensity'].copy()
            
            # Replace values within determined window with interpolated values
            cleaned_intensity.iloc[window_start:window_end + 1] = interpolated_values

            # Store cleaned spectrum
            cleaned_spectrum = pd.DataFrame({
                'Wavelength': spectrum_data['Wavelength'],
                'Corrected_Intensity': cleaned_intensity,
                'Spectrum_ID': spectrum_id
            })

            cleaned_spectra.append(cleaned_spectrum)
            
            # Print information: interpolation & cosmic ray replacement
            print(f"Window start: {window_start}, Window end: {window_end}")
            print("Interpolated values:")
            print(interpolated_values)
            
            # Print information: cleaned_spectrum
            print(f"Cleaned Spectrum {i + 1}:")
            print(cleaned_spectrum.head())
            print()

            # Print information: cleaned intensity before & after replacement
            print("Cleaned intensity before replacement:")
            print(spectrum_data['Corrected_Intensity'].iloc[window_start:window_end + 1])
            print("Cleaned intensity after replacement:")
            print(cleaned_spectrum['Corrected_Intensity'].iloc[window_start:window_end + 1])
            
        except Exception as e:
            print(f"Error processing spectrum {spectrum_id}: {e}")
    else:
        print(f"No data for spectrum {spectrum_id}")

# Save cleaned spectra
output_file_path = '/kaggle/working/cleaned_spectra.csv'

# Print information: cleaned spectra
if cleaned_spectra:
    cleaned_data = pd.concat(cleaned_spectra, ignore_index=True)
    cleaned_data.to_csv(output_file_path, index=False)
    print(f"\nCleaned spectra saved to {output_file_path}")
else:
    print("\nNo cleaned spectra to save")
    
#Plot
plt.figure(figsize=(16, 10), dpi=150)
plt.suptitle('Cosmic Rays Removal', fontsize=16)

# Plot original spectra
plt.subplot(2, 1, 1)
for i in range(num_spectra):
    plt.plot(combined_data[combined_data['Spectrum_ID'] == f'Spectrum_{i + 1}']['Wavelength'],
             combined_data[combined_data['Spectrum_ID'] == f'Spectrum_{i + 1}']['Corrected_Intensity'],color="blue",
             label=f'Spectrum {i + 1}')
plt.title('Original Spectra')
plt.xlabel('Wavelength')
plt.ylabel('Corrected_Intensity')

# Plot cleaned spectra
plt.subplot(2, 1, 2)
for i in range(num_spectra):
    if len(cleaned_spectra) > i:
        plt.plot(cleaned_spectra[i]['Wavelength'], cleaned_spectra[i]['Corrected_Intensity'], color='orange',
                 label=f'Spectrum {i + 1}')

plt.title('Cleaned Spectra')
plt.xlabel('Wavelength')
plt.ylabel('Corrected_Intensity')
plt.subplots_adjust(left=0.1, bottom=0.1, right=0.9, top=0.9, wspace=0.4, hspace=0.4) # adjust margins
plt.show()
# Out:
# Loaded combined data:
#   Spectrum_ID   Wavelength  Corrected_Intensity
# 0  Spectrum_1  1705.003906             1.007219
# 1  Spectrum_1  1703.941406           -11.469430
# 2  Spectrum_1  1702.878906             1.931192
# 3  Spectrum_1  1701.816406            -1.132275
# 4  Spectrum_1  1700.753906             2.869620
#
# Data information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 136010 entries, 0 to 136009
# Data columns (total 3 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Spectrum_ID          136010 non-null  object
#  1   Wavelength           136010 non-null  float64
#  2   Corrected_Intensity  136010 non-null  float64
# dtypes: float64(2), object(1)
# memory usage: 3.1+ MB
# None
#
# Unique Spectrum_IDs:
# ['Spectrum_1' 'Spectrum_2' 'Spectrum_3' 'Spectrum_4' 'Spectrum_5'
#  'Spectrum_6' 'Spectrum_7' 'Spectrum_8' 'Spectrum_9' 'Spectrum_10'
#  'Spectrum_11' 'Spectrum_12' 'Spectrum_13' 'Spectrum_14' 'Spectrum_15'
#  'Spectrum_16' 'Spectrum_17' 'Spectrum_18' 'Spectrum_19' 'Spectrum_20'
#  'Spectrum_21' 'Spectrum_22' 'Spectrum_23' 'Spectrum_24' 'Spectrum_25'
#  'Spectrum_26' 'Spectrum_27' 'Spectrum_28' 'Spectrum_29' 'Spectrum_30'
#  'Spectrum_31' 'Spectrum_32' 'Spectrum_33' 'Spectrum_34' 'Spectrum_35'
#  'Spectrum_36' 'Spectrum_37' 'Spectrum_38' 'Spectrum_39' 'Spectrum_40'
#  'Spectrum_41' 'Spectrum_42' 'Spectrum_43' 'Spectrum_44' 'Spectrum_45'
#  'Spectrum_46' 'Spectrum_47' 'Spectrum_48' 'Spectrum_49' 'Spectrum_50'
#  'Spectrum_51' 'Spectrum_52' 'Spectrum_53' 'Spectrum_54' 'Spectrum_55'
#  'Spectrum_56' 'Spectrum_57' 'Spectrum_58' 'Spectrum_59' 'Spectrum_60'
#  'Spectrum_61' 'Spectrum_62' 'Spectrum_63' 'Spectrum_64' 'Spectrum_65'
#  'Spectrum_66' 'Spectrum_67' 'Spectrum_68' 'Spectrum_69' 'Spectrum_70'
#  'Spectrum_71' 'Spectrum_72' 'Spectrum_73' 'Spectrum_74' 'Spectrum_75'
#  'Spectrum_76' 'Spectrum_77' 'Spectrum_78' 'Spectrum_79' 'Spectrum_80'
#  'Spectrum_81' 'Spectrum_82' 'Spectrum_83' 'Spectrum_84' 'Spectrum_85'
#  'Spectrum_86' 'Spectrum_87' 'Spectrum_88' 'Spectrum_89' 'Spectrum_90'
#  'Spectrum_91' 'Spectrum_92' 'Spectrum_93' 'Spectrum_94' 'Spectrum_95'
#  'Spectrum_96' 'Spectrum_97' 'Spectrum_98' 'Spectrum_99' 'Spectrum_100'
#  'Spectrum_101' 'Spectrum_102' 'Spectrum_103' 'Spectrum_104'
#  'Spectrum_105' 'Spectrum_106' 'Spectrum_107' 'Spectrum_108'
#  'Spectrum_109' 'Spectrum_110' 'Spectrum_111' 'Spectrum_112'
#  'Spectrum_113' 'Spectrum_114' 'Spectrum_115' 'Spectrum_116'
#  'Spectrum_117' 'Spectrum_118' 'Spectrum_119' 'Spectrum_120'
#  'Spectrum_121' 'Spectrum_122' 'Spectrum_123' 'Spectrum_124'
#  'Spectrum_125' 'Spectrum_126' 'Spectrum_127' 'Spectrum_128'
#  'Spectrum_129' 'Spectrum_130' 'Spectrum_131' 'Spectrum_132'
#  'Spectrum_133' 'Spectrum_134']
# Window start: 825, Window end: 826
# Interpolated values:
# [19.17736445 33.37470101]
# Cleaned Spectrum 1:
#     Wavelength  Corrected_Intensity Spectrum_ID
# 0  1705.003906             1.007219  Spectrum_1
# 1  1703.941406           -11.469430  Spectrum_1
# 2  1702.878906             1.931192  Spectrum_1
# 3  1701.816406            -1.132275  Spectrum_1
# 4  1700.753906             2.869620  Spectrum_1
#
# Cleaned intensity before replacement:
# 825    19.177364
# 826    33.374701
# Name: Corrected_Intensity, dtype: float64
# Cleaned intensity after replacement:
# 825    19.177364
# 826    33.374701
# Name: Corrected_Intensity, dtype: float64
# Window start: 813, Window end: 816
# Interpolated values:
# [ 2.11450085 -1.36676405 -4.84802896 -8.32929386]
# Cleaned Spectrum 2:
#        Wavelength  Corrected_Intensity Spectrum_ID
# 1015  1705.003906            -4.384662  Spectrum_2
# 1016  1703.941406           -21.428281  Spectrum_2
# 1017  1702.878906            -0.838912  Spectrum_2
# 1018  1701.816406            17.398272  Spectrum_2
# 1019  1700.753906             5.059408  Spectrum_2
#
# Cleaned intensity before replacement:
# 1828     3.729969
# 1829   -14.274412
# 1830    16.120865
# 1831   -18.006007
# Name: Corrected_Intensity, dtype: float64
# Cleaned intensity after replacement:
# 1828    2.114501
# 1829   -1.366764
# 1830   -4.848029
# 1831   -8.329294
# Name: Corrected_Intensity, dtype: float64
# Window start: 730, Window end: 733
# Interpolated values:
# [-2.96035208  0.05944768  3.07924743  6.09904719]
# Cleaned Spectrum 3:
#        Wavelength  Corrected_Intensity Spectrum_ID
# 2030  1705.003906             4.132089  Spectrum_3
# 2031  1703.941406            -5.583037  Spectrum_3
# 2032  1702.878906             5.851052  Spectrum_3
# 2033  1701.816406            21.991009  Spectrum_3
# 2034  1700.753906           -13.615804  Spectrum_3
#
# Cleaned intensity before replacement:
# 2760    -4.805279
# 2761    -6.706982
# 2762    22.146887
# 2763    -4.357236
# Name: Corrected_Intensity, dtype: float64
# Cleaned intensity after replacement:
# 2760   -2.960352
# 2761    0.059448
# 2762    3.079247
# 2763    6.099047
# Name: Corrected_Intensity, dtype: float64
# Window start: 649, Window end: 651
# Interpolated values:
# [-11.13923117  -1.63040098   7.87842921]
# Cleaned Spectrum 4:
#        Wavelength  Corrected_Intensity Spectrum_ID
# 3045  1705.003906           -15.968652  Spectrum_4
# 3046  1703.941406            18.933077  Spectrum_4
# 3047  1702.878906           -19.152009  Spectrum_4
# 3048  1701.816406            18.062544  Spectrum_4
# 3049  1700.753906             1.172490  Spectrum_4
#
# Cleaned intensity before replacement:
# 3694    -4.541329
# 3695   -14.826205
# 3696    14.476331
# Name: Corrected_Intensity, dtype: float64
# Cleaned intensity after replacement:
# 3694   -11.139231
# 3695    -1.630401
# 3696     7.878429
# Name: Corrected_Intensity, dtype: float64
# Window start: 684, Window end: 687
# Interpolated values:
# [-2.39359577  1.69233109  5.77825795  9.86418481]
# Cleaned Spectrum 5:
#        Wavelength  Corrected_Intensity Spectrum_ID
# 4060  1705.003906            14.736472  Spectrum_5
# 4061  1703.941406            -2.075636  Spectrum_5
# 4062  1702.878906           -14.216814  Spectrum_5
# 4063  1701.816406            11.291676  Spectrum_5
# 4064  1700.753906            15.627946  Spectrum_5
#
# Cleaned intensity before replacement:
# 4744    -5.290117
# 4745    -5.135716
# 4746    28.123916
# 4747    -2.756905
# Name: Corrected_Intensity, dtype: float64
# Cleaned intensity after replacement:
# 4744   -2.393596
# 4745    1.692331
# 4746    5.778258
# 4747    9.864185
# Name: Corrected_Intensity, dtype: float64
# Window start: 910, Window end: 913
# Interpolated values:
# [ 0.37446522 -1.67011181 -3.71468883 -5.75926586]
# Cleaned Spectrum 6:
#        Wavelength  Corrected_Intensity Spectrum_ID
# 5075  1705.003906           -16.310502  Spectrum_6
# 5076  1703.941406            -4.667735  Spectrum_6
# 5077  1702.878906           -11.895827  Spectrum_6
# 5078  1701.816406             4.407506  Spectrum_6
# 5079  1700.753906            -7.516001  Spectrum_6
#
# Cleaned intensity before replacement:
# 5985     8.480026
# 5986   -26.970492
# 5987    22.569389
# 5988   -14.848525
# Name: Corrected_Intensity, dtype: float64
# Cleaned intensity after replacement:
# 5985    0.374465
# 5986   -1.670112
# 5987   -3.714689
# 5988   -5.759266
# Name: Corrected_Intensity, dtype: float64
# Window start: 721, Window end: 723
# Interpolated values:
# [-15.06405029   0.51283642  16.08972314]
# Cleaned Spectrum 7:
#        Wavelength  Corrected_Intensity Spectrum_ID
# 6090  1705.003906            -1.180372  Spectrum_7
# 6091  1703.941406             1.024923  Spectrum_7
# 6092  1702.878906            26.713291  Spectrum_7
# 6093  1701.816406           -11.120454  Spectrum_7
# 6094  1700.753906            -8.951255  Spectrum_7
#
# Cleaned intensity before replacement:
# 6811    -5.820347
# 6812   -17.974570
# 6813    25.333426
# Name: Corrected_Intensity, dtype: float64
# Cleaned intensity after replacement:
# 6811   -15.064050
# 6812     0.512836
# 6813    16.089723
# Name: Corrected_Intensity, dtype: float64
# Window start: 639, Window end: 643
# Interpolated values:
# [1.57756169 1.34002879 1.10249589 0.86496299 0.62743009]
# Cleaned Spectrum 8:
#        Wavelength  Corrected_Intensity Spectrum_ID
# 7105  1705.003906            21.756946  Spectrum_8
# 7106  1703.941406           -11.401141  Spectrum_8
# 7107  1702.878906            21.282569  Spectrum_8
# 7108  1701.816406            -4.852784  Spectrum_8
# 7109  1700.753906            18.419668  Spectrum_8
#
# Cleaned intensity before replacement:
# 7744     7.009050
# 7745   -17.866914
# 7746     3.189513
# 7747    32.585804
# 7748   -19.404973
# Name: Corrected_Intensity, dtype: float64
# Cleaned intensity after replacement:
# 7744    1.577562
# 7745    1.340029
# 7746    1.102496
# 7747    0.864963
# 7748    0.627430
# Name: Corrected_Intensity, dtype: float64
# Window start: 858, Window end: 861
# Interpolated values:
# [6.9395843  6.29216981 5.64475532 4.99734083]
# Cleaned Spectrum 9:
#        Wavelength  Corrected_Intensity Spectrum_ID
# 8120  1705.003906            -8.011607  Spectrum_9
# 8121  1703.941406           -15.344042  Spectrum_9
# 8122  1702.878906            -1.528556  Spectrum_9
# 8123  1701.816406            24.048976  Spectrum_9
# 8124  1700.753906            14.340613  Spectrum_9
#
# Cleaned intensity before replacement:
# 8978     3.743553
# 8979    -0.101330
# 8980    28.019850
# 8981    -7.788222
# Name: Corrected_Intensity, dtype: float64
# Cleaned intensity after replacement:
# 8978    6.939584
# 8979    6.292170
# 8980    5.644755
# 8981    4.997341
# Name: Corrected_Intensity, dtype: float64
# Window start: 903, Window end: 905
# Interpolated values:
# [-11.68735493   2.26670398  16.22076289]
# Cleaned Spectrum 10:
#        Wavelength  Corrected_Intensity  Spectrum_ID
# 9135  1705.003906            27.795988  Spectrum_10
# 9136  1703.941406            22.746052  Spectrum_10
# 9137  1702.878906            27.073969  Spectrum_10
# 9138  1701.816406            19.642838  Spectrum_10
# 9139  1700.753906             5.162938  Spectrum_10
#
# Cleaned intensity before replacement:
# 10038    -3.110539
# 10039   -14.886927
# 10040    24.797578
# Name: Corrected_Intensity, dtype: float64
# Cleaned intensity after replacement:
# 10038   -11.687355
# 10039     2.266704
# 10040    16.220763
# Name: Corrected_Intensity, dtype: float64
# Window start: 707, Window end: 710
# Interpolated values:
# [-1.24994773  4.44183654 10.13362081 15.82540508]
# Cleaned Spectrum 11:
#         Wavelength  Corrected_Intensity  Spectrum_ID
# 10150  1705.003906             2.895335  Spectrum_11
# 10151  1703.941406            -6.977522  Spectrum_11
# 10152  1702.878906            16.066587  Spectrum_11
# 10153  1701.816406            15.584016  Spectrum_11
# 10154  1700.753906            17.459978  Spectrum_11
#
# Cleaned intensity before replacement:
# 10857     4.517001
# 10858     0.528005
# 10859     0.660439
# 10860    23.445470
# Name: Corrected_Intensity, dtype: float64
# Cleaned intensity after replacement:
# 10857    -1.249948
# 10858     4.441837
# 10859    10.133621
# 10860    15.825405
# Name: Corrected_Intensity, dtype: float64
# Window start: 892, Window end: 895
# Interpolated values:
# [16.30971599 19.01801675 21.7263175  24.43461826]
# Cleaned Spectrum 12:
#         Wavelength  Corrected_Intensity  Spectrum_ID
# 11165  1705.003906             4.284419  Spectrum_12
# 11166  1703.941406             1.361461  Spectrum_12
# 11167  1702.878906             7.819639  Spectrum_12
# 11168  1701.816406            -9.241687  Spectrum_12
# 11169  1700.753906           -30.993556  Spectrum_12
#
# Cleaned intensity before replacement:
# 12057    19.682712
# 12058     3.940157
# 12059    41.763048
# 12060    16.102752
# Name: Corrected_Intensity, dtype: float64
# Cleaned intensity after replacement:
# 12057    16.309716
# 12058    19.018017
# 12059    21.726318
# 12060    24.434618
# Name: Corrected_Intensity, dtype: float64
# Window start: 768, Window end: 772
# Interpolated values:
# [ 1.94956783  0.55981142 -0.82994499 -2.21970141 -3.60945782]
# Cleaned Spectrum 13:
#         Wavelength  Corrected_Intensity  Spectrum_ID
# 12180  1705.003906             0.653522  Spectrum_13
# 12181  1703.941406            -4.372033  Spectrum_13
# 12182  1702.878906            42.320825  Spectrum_13
# 12183  1701.816406            -5.097076  Spectrum_13
# 12184  1700.753906             8.661279  Spectrum_13
#
# Cleaned intensity before replacement:
# 12948    -8.223945
# 12949    -5.951283
# 12950    32.946715
# 12951    -9.545689
# 12952   -13.375523
# Name: Corrected_Intensity, dtype: float64
# Cleaned intensity after replacement:
# 12948    1.949568
# 12949    0.559811
# 12950   -0.829945
# 12951   -2.219701
# 12952   -3.609458
# Name: Corrected_Intensity, dtype: float64
# Window start: 717, Window end: 720
# Interpolated values:
# [12.45911361  6.85171168  1.24430974 -4.36309219]
# Cleaned Spectrum 14:
#         Wavelength  Corrected_Intensity  Spectrum_ID
# 13195  1705.003906            -0.272011  Spectrum_14
# 13196  1703.941406             6.554395  Spectrum_14
# 13197  1702.878906            34.525660  Spectrum_14
# 13198  1701.816406            29.555990  Spectrum_14
# 13199  1700.753906            15.183445  Spectrum_14
#
# Cleaned intensity before replacement:
# 13912    13.078297
# 13913    -3.223656
# 13914    19.537494
# 13915   -13.200092
# Name: Corrected_Intensity, dtype: float64
# Cleaned intensity after replacement:
# 13912    12.459114
# 13913     6.851712
# 13914     1.244310
# 13915    -4.363092
# Name: Corrected_Intensity, dtype: float64
# Window start: 803, Window end: 806
# Interpolated values:
# [ 4.37594026  1.90165715 -0.57262597 -3.04690908]
# Cleaned Spectrum 15:
#         Wavelength  Corrected_Intensity  Spectrum_ID
# 14210  1705.003906           -15.373821  Spectrum_15
# 14211  1703.941406             7.818481  Spectrum_15
# 14212  1702.878906            -1.957836  Spectrum_15
# 14213  1701.816406            -2.316023  Spectrum_15
# 14214  1700.753906            18.499428  Spectrum_15
#
# Cleaned intensity before replacement:
# 15013    10.035874
# 15014   -14.063656
# 15015    14.378199
# 15016    -7.692354
# Name: Corrected_Intensity, dtype: float64
# Cleaned intensity after replacement:
# 15013    4.375940
# 15014    1.901657
# 15015   -0.572626
# 15016   -3.046909
# Name: Corrected_Intensity, dtype: float64
# Window start: 894, Window end: 897
# Interpolated values:
# [22.88855124 18.61285905 14.33716686 10.06147468]
# Cleaned Spectrum 16:
#         Wavelength  Corrected_Intensity  Spectrum_ID
# 15225  1705.003906           -16.861269  Spectrum_16
# 15226  1703.941406            -3.566780  Spectrum_16
# 15227  1702.878906            -9.105448  Spectrum_16
# 15228  1701.816406            18.302237  Spectrum_16
# 15229  1700.753906            10.428392  Spectrum_16
#
# Cleaned intensity before replacement:
# 16119    26.261294
# 16120     6.514587
# 16121    28.415483
# 16122     4.708688
# Name: Corrected_Intensity, dtype: float64
# Cleaned intensity after replacement:
# 16119    22.888551
# 16120    18.612859
# 16121    14.337167
# 16122    10.061475
# Name: Corrected_Intensity, dtype: float64
# Window start: 998, Window end: 1001
# Interpolated values:
# [-3.19839603 -1.28462844  0.62913915  2.54290673]
# Cleaned Spectrum 17:
#         Wavelength  Corrected_Intensity  Spectrum_ID
# 16240  1705.003906            11.640166  Spectrum_17
# 16241  1703.941406            -5.365049  Spectrum_17
# 16242  1702.878906            -3.570272  Spectrum_17
# 16243  1701.816406           -18.236417  Spectrum_17
# 16244  1700.753906           -18.777747  Spectrum_17
#
# Cleaned intensity before replacement:
# 17238    -4.364028
# 17239   -10.395942
# 17240    22.348663
# 17241    -8.899671
# Name: Corrected_Intensity, dtype: float64
# Cleaned intensity after replacement:
# 17238   -3.198396
# 17239   -1.284628
# 17240    0.629139
# 17241    2.542907
# Name: Corrected_Intensity, dtype: float64
# Window start: 650, Window end: 654
# Interpolated values:
# [20.72598404 15.41369487 10.1014057   4.78911653 -0.52317263]
# Cleaned Spectrum 18:
#         Wavelength  Corrected_Intensity  Spectrum_ID
# 17255  1705.003906            -4.591081  Spectrum_18
# 17256  1703.941406            -2.667963  Spectrum_18
# 17257  1702.878906            20.405976  Spectrum_18
# 17258  1701.816406             5.837866  Spectrum_18
# 17259  1700.753906            -4.015063  Spectrum_18
#
# Cleaned intensity before replacement:
# 17905    11.147305
# 17906     7.081385
# 17907    40.509315
# 17908     7.284942
# 17909   -15.515919
# Name: Corrected_Intensity, dtype: float64
# Cleaned intensity after replacement:
# 17905    20.725984
# 17906    15.413695
# 17907    10.101406
# 17908     4.789117
# 17909    -0.523173
# Name: Corrected_Intensity, dtype: float64
# Window start: 688, Window end: 690
# Interpolated values:
# [0.25721043 4.53223137 8.8072523 ]
# Cleaned Spectrum 19:
#         Wavelength  Corrected_Intensity  Spectrum_ID
# 18270  1705.003906            -2.512610  Spectrum_19
# 18271  1703.941406            -7.491217  Spectrum_19
# 18272  1702.878906           -12.501180  Spectrum_19
# 18273  1701.816406           -19.857300  Spectrum_19
# 18274  1700.753906            -3.685450  Spectrum_19
#
# Cleaned intensity before replacement:
# 18958     9.217540
# 18959   -13.388428
# 18960    17.767582
# Name: Corrected_Intensity, dtype: float64
# Cleaned intensity after replacement:
# 18958    0.257210
# 18959    4.532231
# 18960    8.807252
# Name: Corrected_Intensity, dtype: float64
# Window start: 564, Window end: 569
# Interpolated values:
# [33.62936319 27.05762465 20.48588611 13.91414757  7.34240903  0.77067049]
# Cleaned Spectrum 20:
#         Wavelength  Corrected_Intensity  Spectrum_ID
# 19285  1705.003906           -22.168963  Spectrum_20
# 19286  1703.941406            15.004772  Spectrum_20
# 19287  1702.878906           -13.760027  Spectrum_20
# 19288  1701.816406             4.543421  Spectrum_20
# 19289  1700.753906           -14.784770  Spectrum_20
#
# Cleaned intensity before replacement:
# 19849    39.788718
# 19850    18.745094
# 19851     1.945134
# 19852    44.444708
# 19853     4.356895
# 19854    -6.080447
# Name: Corrected_Intensity, dtype: float64
# Cleaned intensity after replacement:
# 19849    33.629363
# 19850    27.057625
# 19851    20.485886
# 19852    13.914148
# 19853     7.342409
# 19854     0.770670
# Name: Corrected_Intensity, dtype: float64
# Window start: 866, Window end: 869
# Interpolated values:
# [-12.97883497   0.23512723  13.44908943  26.66305162]
# Cleaned Spectrum 21:
#         Wavelength  Corrected_Intensity  Spectrum_ID
# 20300  1705.003906             0.179148  Spectrum_21
# 20301  1703.941406            30.712469  Spectrum_21
# 20302  1702.878906            16.457563  Spectrum_21
# 20303  1701.816406            11.621860  Spectrum_21
# 20304  1700.753906           -23.785086  Spectrum_21
#
# Cleaned intensity before replacement:
# 21166    -2.010420
# 21167    -9.737405
# 21168     0.488910
# 21169    38.627349
# Name: Corrected_Intensity, dtype: float64
# Cleaned intensity after replacement:
# 21166   -12.978835
# 21167     0.235127
# 21168    13.449089
# 21169    26.663052
# Name: Corrected_Intensity, dtype: float64
# Window start: 718, Window end: 720
# Interpolated values:
# [-4.11341931  5.31995097 14.75332125]
# Cleaned Spectrum 22:
#         Wavelength  Corrected_Intensity  Spectrum_ID
# 21315  1705.003906            13.354916  Spectrum_22
# 21316  1703.941406            27.161010  Spectrum_22
# 21317  1702.878906           -15.551950  Spectrum_22
# 21318  1701.816406           -25.309530  Spectrum_22
# 21319  1700.753906             0.223057  Spectrum_22
#
# Cleaned intensity before replacement:
# 22033     2.395397
# 22034    -7.697683
# 22035    21.262138
# Name: Corrected_Intensity, dtype: float64
# Cleaned intensity after replacement:
# 22033    -4.113419
# 22034     5.319951
# 22035    14.753321
# Name: Corrected_Intensity, dtype: float64
# Window start: 698, Window end: 701
# Interpolated values:
# [ 0.68344351  0.22402304 -0.23539743 -0.6948179 ]
# Cleaned Spectrum 23:
#         Wavelength  Corrected_Intensity  Spectrum_ID
# 22330  1705.003906            -4.010856  Spectrum_23
# 22331  1703.941406             2.633338  Spectrum_23
# 22332  1702.878906            -0.175149  Spectrum_23
# 22333  1701.816406            15.843943  Spectrum_23
# 22334  1700.753906             5.991077  Spectrum_23
#
# Cleaned intensity before replacement:
# 23028    13.684397
# 23029    -8.858034
# 23030   -21.074144
# 23031    16.225032
# Name: Corrected_Intensity, dtype: float64
# Cleaned intensity after replacement:
# 23028    0.683444
# 23029    0.224023
# 23030   -0.235397
# 23031   -0.694818
# Name: Corrected_Intensity, dtype: float64
# Window start: 680, Window end: 682
# Interpolated values:
# [-0.98039974  5.38989852 11.76019678]
# Cleaned Spectrum 24:
#         Wavelength  Corrected_Intensity  Spectrum_ID
# 23345  1705.003906             9.348101  Spectrum_24
# 23346  1703.941406            25.670999  Spectrum_24
# 23347  1702.878906            23.130183  Spectrum_24
# 23348  1701.816406           -17.046828  Spectrum_24
# 23349  1700.753906           -24.277701  Spectrum_24
#
# Cleaned intensity before replacement:
# 24025     4.542102
# 24026    -5.655105
# 24027    17.282699
# Name: Corrected_Intensity, dtype: float64
# Cleaned intensity after replacement:
# 24025    -0.980400
# 24026     5.389899
# 24027    11.760197
# Name: Corrected_Intensity, dtype: float64
# Window start: 729, Window end: 731
# Interpolated values:
# [-10.09691936  -3.79221974   2.51247988]
# Cleaned Spectrum 25:
#         Wavelength  Corrected_Intensity  Spectrum_ID
# 24360  1705.003906           -26.025473  Spectrum_25
# 24361  1703.941406             1.895950  Spectrum_25
# 24362  1702.878906             1.543069  Spectrum_25
# 24363  1701.816406           -17.624615  Spectrum_25
# 24364  1700.753906             5.557051  Spectrum_25
#
# Cleaned intensity before replacement:
# 25089    -1.892898
# 25090   -20.200263
# 25091    10.716501
# Name: Corrected_Intensity, dtype: float64
# Cleaned intensity after replacement:
# 25089   -10.096919
# 25090    -3.792220
# 25091     2.512480
# Name: Corrected_Intensity, dtype: float64
# Window start: 967, Window end: 969
# Interpolated values:
# [-13.79236518  -3.11828152   7.55580214]
# Cleaned Spectrum 26:
#         Wavelength  Corrected_Intensity  Spectrum_ID
# 25375  1705.003906            15.053824  Spectrum_26
# 25376  1703.941406             2.941229  Spectrum_26
# 25377  1702.878906            11.979992  Spectrum_26
# 25378  1701.816406            -2.504496  Spectrum_26
# 25379  1700.753906             1.837649  Spectrum_26
#
# Cleaned intensity before replacement:
# 26342    -7.610380
# 26343   -15.482251
# 26344    13.737787
# Name: Corrected_Intensity, dtype: float64
# Cleaned intensity after replacement:
# 26342   -13.792365
# 26343    -3.118282
# 26344     7.555802
# Name: Corrected_Intensity, dtype: float64
# Window start: 883, Window end: 886
# Interpolated values:
# [-6.54412802  3.95520899 14.454546   24.95388301]
# Cleaned Spectrum 27:
#         Wavelength  Corrected_Intensity  Spectrum_ID
# 26390  1705.003906            -1.685855  Spectrum_27
# 26391  1703.941406             9.274294  Spectrum_27
# 26392  1702.878906           -15.090485  Spectrum_27
# 26393  1701.816406           -11.206662  Spectrum_27
# 26394  1700.753906             4.446311  Spectrum_27
#
# Cleaned intensity before replacement:
# 27273     2.994262
# 27274    -2.801905
# 27275    -0.646395
# 27276    37.273548
# Name: Corrected_Intensity, dtype: float64
# Cleaned intensity after replacement:
# 27273    -6.544128
# 27274     3.955209
# 27275    14.454546
# 27276    24.953883
# Name: Corrected_Intensity, dtype: float64
# Window start: 826, Window end: 829
# Interpolated values:
# [ 3.36534083  5.73256267  8.09978451 10.46700634]
# Cleaned Spectrum 28:
#         Wavelength  Corrected_Intensity  Spectrum_ID
# 27405  1705.003906           -14.098229  Spectrum_28
# 27406  1703.941406            -2.619904  Spectrum_28
# 27407  1702.878906            -2.933157  Spectrum_28
# 27408  1701.816406             1.462687  Spectrum_28
# 27409  1700.753906            -3.547402  Spectrum_28
#
# Cleaned intensity before replacement:
# 28231    10.202865
# 28232     2.313002
# 28233    -5.573667
# 28234    20.722494
# Name: Corrected_Intensity, dtype: float64
# Cleaned intensity after replacement:
# 28231     3.365341
# 28232     5.732563
# 28233     8.099785
# 28234    10.467006
# Name: Corrected_Intensity, dtype: float64
# Window start: 863, Window end: 866
# Interpolated values:
# [-24.05800436 -13.72144078  -3.3848772    6.95168638]
# Cleaned Spectrum 29:
#         Wavelength  Corrected_Intensity  Spectrum_ID
# 28420  1705.003906           -18.405993  Spectrum_29
# 28421  1703.941406            13.968768  Spectrum_29
# 28422  1702.878906            -7.806555  Spectrum_29
# 28423  1701.816406             5.720323  Spectrum_29
# 28424  1700.753906           -13.679677  Spectrum_29
#
# Cleaned intensity before replacement:
# 29283   -10.287451
# 29284   -28.092432
# 29285   -15.954555
# 29286    20.121802
# Name: Corrected_Intensity, dtype: float64
# Cleaned intensity after replacement:
# 29283   -24.058004
# 29284   -13.721441
# 29285    -3.384877
# 29286     6.951686
# Name: Corrected_Intensity, dtype: float64
# Window start: 747, Window end: 750
# Interpolated values:
# [-22.67919364  -7.41156217   7.8560693   23.12370077]
# Cleaned Spectrum 30:
#         Wavelength  Corrected_Intensity  Spectrum_ID
# 29435  1705.003906           -13.701095  Spectrum_30
# 29436  1703.941406             6.992190  Spectrum_30
# 29437  1702.878906           -26.461065  Spectrum_30
# 29438  1701.816406            20.088514  Spectrum_30
# 29439  1700.753906            19.586247  Spectrum_30
#
# Cleaned intensity before replacement:
# 30182   -17.368440
# 30183   -13.131589
# 30184     3.363861
# 30185    28.025182
# Name: Corrected_Intensity, dtype: float64
# Cleaned intensity after replacement:
# 30182   -22.679194
# 30183    -7.411562
# 30184     7.856069
# 30185    23.123701
# Name: Corrected_Intensity, dtype: float64
# Window start: 938, Window end: 941
# Interpolated values:
# [-9.75588954 -4.09585103  1.56418748  7.22422599]
# Cleaned Spectrum 31:
#         Wavelength  Corrected_Intensity  Spectrum_ID
# 30450  1705.003906            -8.268573  Spectrum_31
# 30451  1703.941406             3.301014  Spectrum_31
# 30452  1702.878906            -6.324957  Spectrum_31
# 30453  1701.816406            14.637984  Spectrum_31
# 30454  1700.753906            12.075771  Spectrum_31
#
# Cleaned intensity before replacement:
# 31388    -2.684830
# 31389   -12.543019
# 31390    -2.754655
# 31391    12.919177
# Name: Corrected_Intensity, dtype: float64
# Cleaned intensity after replacement:
# 31388   -9.755890
# 31389   -4.095851
# 31390    1.564187
# 31391    7.224226
# Name: Corrected_Intensity, dtype: float64
# Window start: 622, Window end: 625
# Interpolated values:
# [-1.37311227  2.72315593  6.81942414 10.91569235]
# Cleaned Spectrum 32:
#         Wavelength  Corrected_Intensity  Spectrum_ID
# 31465  1705.003906           -13.891344  Spectrum_32
# 31466  1703.941406             7.163369  Spectrum_32
# 31467  1702.878906             9.351987  Spectrum_32
# 31468  1701.816406            13.895712  Spectrum_32
# 31469  1700.753906           -16.840124  Spectrum_32
#
# Cleaned intensity before replacement:
# 32087    21.876946
# 32088   -21.995747
# 32089   -13.492944
# 32090    32.696906
# Name: Corrected_Intensity, dtype: float64
# Cleaned intensity after replacement:
# 32087    -1.373112
# 32088     2.723156
# 32089     6.819424
# 32090    10.915692
# Name: Corrected_Intensity, dtype: float64
# Window start: 673, Window end: 675
# Interpolated values:
# [-4.622256    9.01110289 22.64446179]
# Cleaned Spectrum 33:
#         Wavelength  Corrected_Intensity  Spectrum_ID
# 32480  1705.003906             7.673727  Spectrum_33
# 32481  1703.941406            -6.609326  Spectrum_33
# 32482  1702.878906           -16.222308  Spectrum_33
# 32483  1701.816406            -7.008067  Spectrum_33
# 32484  1700.753906             6.911010  Spectrum_33
#
# Cleaned intensity before replacement:
# 33153    -0.129565
# 33154     0.025721
# 33155    27.137153
# Name: Corrected_Intensity, dtype: float64
# Cleaned intensity after replacement:
# 33153    -4.622256
# 33154     9.011103
# 33155    22.644462
# Name: Corrected_Intensity, dtype: float64
# Window start: 879, Window end: 881
# Interpolated values:
# [-14.34654749   6.68614289  27.71883326]
# Cleaned Spectrum 34:
#         Wavelength  Corrected_Intensity  Spectrum_ID
# 33495  1705.003906            32.134856  Spectrum_34
# 33496  1703.941406           -17.533001  Spectrum_34
# 33497  1702.878906            15.124786  Spectrum_34
# 33498  1701.816406            -8.684342  Spectrum_34
# 33499  1700.753906            16.913107  Spectrum_34
#
# Cleaned intensity before replacement:
# 34374    -2.742580
# 34375   -16.521793
# 34376    39.322801
# Name: Corrected_Intensity, dtype: float64
# Cleaned intensity after replacement:
# 34374   -14.346547
# 34375     6.686143
# 34376    27.718833
# Name: Corrected_Intensity, dtype: float64
# Window start: 773, Window end: 777
# Interpolated values:
# [5.85079307 6.83556535 7.82033763 8.80510991 9.78988219]
# Cleaned Spectrum 35:
#         Wavelength  Corrected_Intensity  Spectrum_ID
# 34510  1705.003906           -10.286754  Spectrum_35
# 34511  1703.941406            -3.601552  Spectrum_35
# 34512  1702.878906            -1.653091  Spectrum_35
# 34513  1701.816406           -18.519943  Spectrum_35
# 34514  1700.753906            14.018255  Spectrum_35
#
# Cleaned intensity before replacement:
# 35283     8.698081
# 35284     2.769383
# 35285    -1.123632
# 35286    27.502447
# 35287     1.255410
# Name: Corrected_Intensity, dtype: float64
# Cleaned intensity after replacement:
# 35283    5.850793
# 35284    6.835565
# 35285    7.820338
# 35286    8.805110
# 35287    9.789882
# Name: Corrected_Intensity, dtype: float64
# Window start: 716, Window end: 718
# Interpolated values:
# [-6.64989123  1.71586811 10.08162744]
# Cleaned Spectrum 36:
#         Wavelength  Corrected_Intensity  Spectrum_ID
# 35525  1705.003906             9.183907  Spectrum_36
# 35526  1703.941406            -9.910328  Spectrum_36
# 35527  1702.878906           -10.200342  Spectrum_36
# 35528  1701.816406           -19.896879  Spectrum_36
# 35529  1700.753906            10.398798  Spectrum_36
#
# Cleaned intensity before replacement:
# 36241     3.631683
# 36242   -18.847280
# 36243    20.363201
# Name: Corrected_Intensity, dtype: float64
# Cleaned intensity after replacement:
# 36241    -6.649891
# 36242     1.715868
# 36243    10.081627
# Name: Corrected_Intensity, dtype: float64
# Window start: 830, Window end: 834
# Interpolated values:
# [-1.57108973  0.4083685   2.38782673  4.36728495  6.34674318]
# Cleaned Spectrum 37:
#         Wavelength  Corrected_Intensity  Spectrum_ID
# 36540  1705.003906            19.902706  Spectrum_37
# 36541  1703.941406             3.109953  Spectrum_37
# 36542  1702.878906            -4.296725  Spectrum_37
# 36543  1701.816406            14.181283  Spectrum_37
# 36544  1700.753906             6.784457  Spectrum_37
#
# Cleaned intensity before replacement:
# 37370     1.243834
# 37371   -20.692896
# 37372    27.706904
# 37373     5.773226
# 37374    -2.091936
# Name: Corrected_Intensity, dtype: float64
# Cleaned intensity after replacement:
# 37370   -1.571090
# 37371    0.408369
# 37372    2.387827
# 37373    4.367285
# 37374    6.346743
# Name: Corrected_Intensity, dtype: float64
# Window start: 822, Window end: 824
# Interpolated values:
# [-11.46816551   7.86609889  27.20036329]
# Cleaned Spectrum 38:
#         Wavelength  Corrected_Intensity  Spectrum_ID
# 37555  1705.003906           -27.044256  Spectrum_38
# 37556  1703.941406            -3.680858  Spectrum_38
# 37557  1702.878906            21.983506  Spectrum_38
# 37558  1701.816406           -20.578632  Spectrum_38
# 37559  1700.753906           -27.839688  Spectrum_38
#
# Cleaned intensity before replacement:
# 38377    -2.410693
# 38378   -10.248847
# 38379    36.257836
# Name: Corrected_Intensity, dtype: float64
# Cleaned intensity after replacement:
# 38377   -11.468166
# 38378     7.866099
# 38379    27.200363
# Name: Corrected_Intensity, dtype: float64
# Window start: 982, Window end: 985
# Interpolated values:
# [ 2.61769349  6.63198807 10.64628265 14.66057723]
# Cleaned Spectrum 39:
#         Wavelength  Corrected_Intensity  Spectrum_ID
# 38570  1705.003906           -12.549936  Spectrum_39
# 38571  1703.941406           -10.365063  Spectrum_39
# 38572  1702.878906            20.018554  Spectrum_39
# 38573  1701.816406            -6.064485  Spectrum_39
# 38574  1700.753906           -15.669962  Spectrum_39
#
# Cleaned intensity before replacement:
# 39552    10.206620
# 39553   -13.217216
# 39554    27.577911
# 39555     9.989226
# Name: Corrected_Intensity, dtype: float64
# Cleaned intensity after replacement:
# 39552     2.617693
# 39553     6.631988
# 39554    10.646283
# 39555    14.660577
# Name: Corrected_Intensity, dtype: float64
# Window start: 835, Window end: 838
# Interpolated values:
# [ 0.63769646  6.86230357 13.08691068 19.3115178 ]
# Cleaned Spectrum 40:
#         Wavelength  Corrected_Intensity  Spectrum_ID
# 39585  1705.003906            25.224695  Spectrum_40
# 39586  1703.941406            -5.896424  Spectrum_40
# 39587  1702.878906           -15.877011  Spectrum_40
# 39588  1701.816406            11.793808  Spectrum_40
# 39589  1700.753906            18.294114  Spectrum_40
#
# Cleaned intensity before replacement:
# 40420    14.690124
# 40421    -9.199281
# 40422     3.052796
# 40423    31.354789
# Name: Corrected_Intensity, dtype: float64
# Cleaned intensity after replacement:
# 40420     0.637696
# 40421     6.862304
# 40422    13.086911
# 40423    19.311518
# Name: Corrected_Intensity, dtype: float64
# Window start: 610, Window end: 613
# Interpolated values:
# [-18.41492839 -11.37472385  -4.33451931   2.70568523]
# Cleaned Spectrum 41:
#         Wavelength  Corrected_Intensity  Spectrum_ID
# 40600  1705.003906            13.114348  Spectrum_41
# 40601  1703.941406            -8.604181  Spectrum_41
# 40602  1702.878906             0.240055  Spectrum_41
# 40603  1701.816406             6.736196  Spectrum_41
# 40604  1700.753906             3.829154  Spectrum_41
#
# Cleaned intensity before replacement:
# 41210   -13.795833
# 41211   -28.380176
# 41212    15.819098
# 41213    -5.061576
# Name: Corrected_Intensity, dtype: float64
# Cleaned intensity after replacement:
# 41210   -18.414928
# 41211   -11.374724
# 41212    -4.334519
# 41213     2.705685
# Name: Corrected_Intensity, dtype: float64
# Window start: 982, Window end: 984
# Interpolated values:
# [-11.37121323  -0.82670513   9.71780297]
# Cleaned Spectrum 42:
#         Wavelength  Corrected_Intensity  Spectrum_ID
# 41615  1705.003906           -16.037584  Spectrum_42
# 41616  1703.941406             7.131696  Spectrum_42
# 41617  1702.878906            -0.314005  Spectrum_42
# 41618  1701.816406           -19.514975  Spectrum_42
# 41619  1700.753906            -1.071237  Spectrum_42
#
# Cleaned intensity before replacement:
# 42597    -2.614614
# 42598   -18.339904
# 42599    18.474403
# Name: Corrected_Intensity, dtype: float64
# Cleaned intensity after replacement:
# 42597   -11.371213
# 42598    -0.826705
# 42599     9.717803
# Name: Corrected_Intensity, dtype: float64
# Window start: 760, Window end: 763
# Interpolated values:
# [-5.49542412 -0.46487087  4.56568238  9.59623563]
# Cleaned Spectrum 43:
#         Wavelength  Corrected_Intensity  Spectrum_ID
# 42630  1705.003906            10.267328  Spectrum_43
# 42631  1703.941406             0.288192  Spectrum_43
# 42632  1702.878906            16.171742  Spectrum_43
# 42633  1701.816406             1.474375  Spectrum_43
# 42634  1700.753906            -3.802493  Spectrum_43
#
# Cleaned intensity before replacement:
# 43390     3.880112
# 43391    -8.211029
# 43392    -8.068610
# 43393    20.601150
# Name: Corrected_Intensity, dtype: float64
# Cleaned intensity after replacement:
# 43390   -5.495424
# 43391   -0.464871
# 43392    4.565682
# 43393    9.596236
# Name: Corrected_Intensity, dtype: float64
# Window start: 681, Window end: 686
# Interpolated values:
# [ 11.30171168   5.90926071   0.51680973  -4.87564124 -10.26809221
#  -15.66054319]
# Cleaned Spectrum 44:
#         Wavelength  Corrected_Intensity  Spectrum_ID
# 43645  1705.003906           -22.458996  Spectrum_44
# 43646  1703.941406            -6.586580  Spectrum_44
# 43647  1702.878906            -7.208227  Spectrum_44
# 43648  1701.816406            22.760425  Spectrum_44
# 43649  1700.753906            -3.723976  Spectrum_44
#
# Cleaned intensity before replacement:
# 44326    11.701549
# 44327    -6.830596
# 44328    20.190837
# 44329    -8.683850
# 44330   -12.713518
# 44331   -16.740916
# Name: Corrected_Intensity, dtype: float64
# Cleaned intensity after replacement:
# 44326    11.301712
# 44327     5.909261
# 44328     0.516810
# 44329    -4.875641
# 44330   -10.268092
# 44331   -15.660543
# Name: Corrected_Intensity, dtype: float64
# Window start: 771, Window end: 775
# Interpolated values:
# [ 9.86404211  5.52242179  1.18080147 -3.16081885 -7.50243917]
# Cleaned Spectrum 45:
#         Wavelength  Corrected_Intensity  Spectrum_ID
# 44660  1705.003906            12.803728  Spectrum_45
# 44661  1703.941406            -3.946755  Spectrum_45
# 44662  1702.878906           -16.006295  Spectrum_45
# 44663  1701.816406             7.229283  Spectrum_45
# 44664  1700.753906             4.587187  Spectrum_45
#
# Cleaned intensity before replacement:
# 45431    22.475479
# 45432    -1.802660
# 45433    -7.768666
# 45434   -13.732387
# 45435     6.732241
# Name: Corrected_Intensity, dtype: float64
# Cleaned intensity after replacement:
# 45431    9.864042
# 45432    5.522422
# 45433    1.180801
# 45434   -3.160819
# 45435   -7.502439
# Name: Corrected_Intensity, dtype: float64
# Window start: 995, Window end: 998
# Interpolated values:
# [-5.00449258 -1.30115268  2.40218722  6.10552712]
# Cleaned Spectrum 46:
#         Wavelength  Corrected_Intensity  Spectrum_ID
# 45675  1705.003906           -11.672746  Spectrum_46
# 45676  1703.941406             6.821447  Spectrum_46
# 45677  1702.878906             4.119902  Spectrum_46
# 45678  1701.816406             1.423769  Spectrum_46
# 45679  1700.753906             3.437197  Spectrum_46
#
# Cleaned intensity before replacement:
# 46670     3.725564
# 46671   -11.972706
# 46672    -2.444874
# 46673    12.894086
# Name: Corrected_Intensity, dtype: float64
# Cleaned intensity after replacement:
# 46670   -5.004493
# 46671   -1.301153
# 46672    2.402187
# 46673    6.105527
# Name: Corrected_Intensity, dtype: float64
# Window start: 759, Window end: 762
# Interpolated values:
# [-17.92592749  -8.97996883  -0.03401017   8.91194849]
# Cleaned Spectrum 47:
#         Wavelength  Corrected_Intensity  Spectrum_ID
# 46690  1705.003906            -0.157260  Spectrum_47
# 46691  1703.941406           -14.782682  Spectrum_47
# 46692  1702.878906            -1.206027  Spectrum_47
# 46693  1701.816406            -4.093729  Spectrum_47
# 46694  1700.753906            16.548300  Spectrum_47
#
# Cleaned intensity before replacement:
# 47449   -10.384200
# 47450   -14.280208
# 47451   -12.058715
# 47452    18.695165
# Name: Corrected_Intensity, dtype: float64
# Cleaned intensity after replacement:
# 47449   -17.925927
# 47450    -8.979969
# 47451    -0.034010
# 47452     8.911948
# Name: Corrected_Intensity, dtype: float64
# Window start: 816, Window end: 819
# Interpolated values:
# [-5.57917045 -2.19165511  1.19586024  4.58337558]
# Cleaned Spectrum 48:
#         Wavelength  Corrected_Intensity  Spectrum_ID
# 47705  1705.003906             4.155493  Spectrum_48
# 47706  1703.941406            -5.291384  Spectrum_48
# 47707  1702.878906            -0.651218  Spectrum_48
# 47708  1701.816406           -10.125759  Spectrum_48
# 47709  1700.753906           -12.538827  Spectrum_48
#
# Cleaned intensity before replacement:
# 48521     3.289425
# 48522   -22.749569
# 48523    15.705902
# 48524     1.762652
# Name: Corrected_Intensity, dtype: float64
# Cleaned intensity after replacement:
# 48521   -5.579170
# 48522   -2.191655
# 48523    1.195860
# 48524    4.583376
# Name: Corrected_Intensity, dtype: float64
# Window start: 624, Window end: 627
# Interpolated values:
# [6.25748874 6.40471155 6.55193436 6.69915717]
# Cleaned Spectrum 49:
#         Wavelength  Corrected_Intensity  Spectrum_ID
# 48720  1705.003906            12.806109  Spectrum_49
# 48721  1703.941406             5.683302  Spectrum_49
# 48722  1702.878906           -10.891581  Spectrum_49
# 48723  1701.816406            14.887238  Spectrum_49
# 48724  1700.753906             3.026590  Spectrum_49
#
# Cleaned intensity before replacement:
# 49344    -1.069774
# 49345     5.358522
# 49346    30.626100
# 49347    -9.001557
# Name: Corrected_Intensity, dtype: float64
# Cleaned intensity after replacement:
# 49344    6.257489
# 49345    6.404712
# 49346    6.551934
# 49347    6.699157
# Name: Corrected_Intensity, dtype: float64
# Window start: 735, Window end: 737
# Interpolated values:
# [-5.07656964  4.34747193 13.7715135 ]
# Cleaned Spectrum 50:
#         Wavelength  Corrected_Intensity  Spectrum_ID
# 49735  1705.003906           -12.127873  Spectrum_50
# 49736  1703.941406            -9.953974  Spectrum_50
# 49737  1702.878906           -14.881956  Spectrum_50
# 49738  1701.816406           -10.393992  Spectrum_50
# 49739  1700.753906            19.969663  Spectrum_50
#
# Cleaned intensity before replacement:
# 50470     5.507682
# 50471   -16.821031
# 50472    24.355765
# Name: Corrected_Intensity, dtype: float64
# Cleaned intensity after replacement:
# 50470    -5.076570
# 50471     4.347472
# 50472    13.771513
# Name: Corrected_Intensity, dtype: float64
# Window start: 997, Window end: 1001
# Interpolated values:
# [-1.25135787 -0.72926531 -0.20717275  0.31491981  0.83701237]
# Cleaned Spectrum 51:
#         Wavelength  Corrected_Intensity  Spectrum_ID
# 50750  1705.003906           -17.125426  Spectrum_51
# 50751  1703.941406           -40.960659  Spectrum_51
# 50752  1702.878906            -6.004575  Spectrum_51
# 50753  1701.816406           -29.866989  Spectrum_51
# 50754  1700.753906            12.143493  Spectrum_51
#
# Cleaned intensity before replacement:
# 51747    -0.481179
# 51748    -4.604809
# 51749    -6.794049
# 51750    22.034590
# 51751   -11.190416
# Name: Corrected_Intensity, dtype: float64
# Cleaned intensity after replacement:
# 51747   -1.251358
# 51748   -0.729265
# 51749   -0.207173
# 51750    0.314920
# 51751    0.837012
# Name: Corrected_Intensity, dtype: float64
# Window start: 801, Window end: 804
# Interpolated values:
# [-3.08530539  2.3605198   7.806345   13.25217019]
# Cleaned Spectrum 52:
#         Wavelength  Corrected_Intensity  Spectrum_ID
# 51765  1705.003906             0.719788  Spectrum_52
# 51766  1703.941406            21.720327  Spectrum_52
# 51767  1702.878906           -25.557113  Spectrum_52
# 51768  1701.816406            -2.239314  Spectrum_52
# 51769  1700.753906           -37.728097  Spectrum_52
#
# Cleaned intensity before replacement:
# 52566     8.840772
# 52567    -7.141346
# 52568    -8.968157
# 52569    27.602460
# Name: Corrected_Intensity, dtype: float64
# Cleaned intensity after replacement:
# 52566    -3.085305
# 52567     2.360520
# 52568     7.806345
# 52569    13.252170
# Name: Corrected_Intensity, dtype: float64
# Window start: 720, Window end: 723
# Interpolated values:
# [-20.95764961 -12.77764044  -4.59763128   3.58237788]
# Cleaned Spectrum 53:
#         Wavelength  Corrected_Intensity  Spectrum_ID
# 52780  1705.003906            16.466880  Spectrum_53
# 52781  1703.941406            -7.263337  Spectrum_53
# 52782  1702.878906            32.502384  Spectrum_53
# 52783  1701.816406             1.683481  Spectrum_53
# 52784  1700.753906            17.921251  Spectrum_53
#
# Cleaned intensity before replacement:
# 53500   -13.562498
# 53501   -17.502883
# 53502   -17.332602
# 53503    13.647439
# Name: Corrected_Intensity, dtype: float64
# Cleaned intensity after replacement:
# 53500   -20.957650
# 53501   -12.777640
# 53502    -4.597631
# 53503     3.582378
# Name: Corrected_Intensity, dtype: float64
# Window start: 846, Window end: 851
# Interpolated values:
# [-0.22003354  0.22174364  0.66352083  1.10529802  1.54707521  1.9888524 ]
# Cleaned Spectrum 54:
#         Wavelength  Corrected_Intensity  Spectrum_ID
# 53795  1705.003906             6.661488  Spectrum_54
# 53796  1703.941406            20.640577  Spectrum_54
# 53797  1702.878906            32.227400  Spectrum_54
# 53798  1701.816406            -0.884159  Spectrum_54
# 53799  1700.753906           -12.812252  Spectrum_54
#
# Cleaned intensity before replacement:
# 54641     8.175648
# 54642   -13.704498
# 54643   -11.542839
# 54644    24.657552
# 54645     4.788206
# 54646    -7.067612
# Name: Corrected_Intensity, dtype: float64
# Cleaned intensity after replacement:
# 54641   -0.220034
# 54642    0.221744
# 54643    0.663521
# 54644    1.105298
# 54645    1.547075
# 54646    1.988852
# Name: Corrected_Intensity, dtype: float64
# Window start: 824, Window end: 828
# Interpolated values:
# [ 1.3756266   4.59364479  7.81166298 11.02968117 14.24769936]
# Cleaned Spectrum 55:
#         Wavelength  Corrected_Intensity  Spectrum_ID
# 54810  1705.003906            -7.679689  Spectrum_55
# 54811  1703.941406            -8.071473  Spectrum_55
# 54812  1702.878906            -1.442386  Spectrum_55
# 54813  1701.816406           -11.276528  Spectrum_55
# 54814  1700.753906            18.884841  Spectrum_55
#
# Cleaned intensity before replacement:
# 55634     2.583659
# 55635    -5.264651
# 55636     7.008387
# 55637    37.378991
# 55638    -2.648071
# Name: Corrected_Intensity, dtype: float64
# Cleaned intensity after replacement:
# 55634     1.375627
# 55635     4.593645
# 55636     7.811663
# 55637    11.029681
# 55638    14.247699
# Name: Corrected_Intensity, dtype: float64
# Window start: 717, Window end: 719
# Interpolated values:
# [-13.75643978  -3.32120128   7.11403722]
# Cleaned Spectrum 56:
#         Wavelength  Corrected_Intensity  Spectrum_ID
# 55825  1705.003906            12.257673  Spectrum_56
# 55826  1703.941406             0.138897  Spectrum_56
# 55827  1702.878906            -0.243217  Spectrum_56
# 55828  1701.816406            22.904908  Spectrum_56
# 55829  1700.753906           -12.752183  Spectrum_56
#
# Cleaned intensity before replacement:
# 56542    -5.533053
# 56543   -19.767975
# 56544    15.337424
# Name: Corrected_Intensity, dtype: float64
# Cleaned intensity after replacement:
# 56542   -13.756440
# 56543    -3.321201
# 56544     7.114037
# Name: Corrected_Intensity, dtype: float64
# Window start: 968, Window end: 972
# Interpolated values:
# [-5.53190386 -4.82238381 -4.11286377 -3.40334372 -2.69382367]
# Cleaned Spectrum 57:
#         Wavelength  Corrected_Intensity  Spectrum_ID
# 56840  1705.003906            -5.930459  Spectrum_57
# 56841  1703.941406            -1.573589  Spectrum_57
# 56842  1702.878906           -16.072292  Spectrum_57
# 56843  1701.816406           -11.740688  Spectrum_57
# 56844  1700.753906            -0.349123  Spectrum_57
#
# Cleaned intensity before replacement:
# 57808     1.881019
# 57809    -5.993058
# 57810   -11.915797
# 57811   -13.937145
# 57812     9.400663
# Name: Corrected_Intensity, dtype: float64
# Cleaned intensity after replacement:
# 57808   -5.531904
# 57809   -4.822384
# 57810   -4.112864
# 57811   -3.403344
# 57812   -2.693824
# Name: Corrected_Intensity, dtype: float64
# Window start: 951, Window end: 954
# Interpolated values:
# [ 7.32942992  4.56518751  1.8009451  -0.96329731]
# Cleaned Spectrum 58:
#         Wavelength  Corrected_Intensity  Spectrum_ID
# 57855  1705.003906            -0.492544  Spectrum_58
# 57856  1703.941406             8.470602  Spectrum_58
# 57857  1702.878906             0.932416  Spectrum_58
# 57858  1701.816406             2.812966  Spectrum_58
# 57859  1700.753906            -2.357364  Spectrum_58
#
# Cleaned intensity before replacement:
# 58806     3.214942
# 58807    -0.723359
# 58808    24.721500
# 58809   -14.480818
# Name: Corrected_Intensity, dtype: float64
# Cleaned intensity after replacement:
# 58806    7.329430
# 58807    4.565188
# 58808    1.800945
# 58809   -0.963297
# Name: Corrected_Intensity, dtype: float64
# Window start: 643, Window end: 645
# Interpolated values:
# [ 0.73988647 -2.28941291 -5.31871228]
# Cleaned Spectrum 59:
#         Wavelength  Corrected_Intensity  Spectrum_ID
# 58870  1705.003906            23.378661  Spectrum_59
# 58871  1703.941406            -5.234963  Spectrum_59
# 58872  1702.878906             1.427719  Spectrum_59
# 58873  1701.816406           -10.726912  Spectrum_59
# 58874  1700.753906            10.056913  Spectrum_59
#
# Cleaned intensity before replacement:
# 59513    13.604817
# 59514   -28.019273
# 59515     7.546218
# Name: Corrected_Intensity, dtype: float64
# Cleaned intensity after replacement:
# 59513    0.739886
# 59514   -2.289413
# 59515   -5.318712
# Name: Corrected_Intensity, dtype: float64
# Window start: 702, Window end: 704
# Interpolated values:
# [-8.56737897  5.99846878 20.56431654]
# Cleaned Spectrum 60:
#         Wavelength  Corrected_Intensity  Spectrum_ID
# 59885  1705.003906            -7.734309  Spectrum_60
# 59886  1703.941406           -36.165837  Spectrum_60
# 59887  1702.878906             5.980270  Spectrum_60
# 59888  1701.816406            -1.288238  Spectrum_60
# 59889  1700.753906            -1.495410  Spectrum_60
#
# Cleaned intensity before replacement:
# 60587    -4.444017
# 60588    -2.248255
# 60589    24.687679
# Name: Corrected_Intensity, dtype: float64
# Cleaned intensity after replacement:
# 60587    -8.567379
# 60588     5.998469
# 60589    20.564317
# Name: Corrected_Intensity, dtype: float64
# Window start: 878, Window end: 880
# Interpolated values:
# [-2.33832167  7.67868564 17.69569295]
# Cleaned Spectrum 61:
#         Wavelength  Corrected_Intensity  Spectrum_ID
# 60900  1705.003906             1.122346  Spectrum_61
# 60901  1703.941406             3.193052  Spectrum_61
# 60902  1702.878906             0.542275  Spectrum_61
# ...
# 114699  1700.753906             2.270505  Spectrum_114
#
# Cleaned intensity before replacement:
# 115389    12.934299
# 115390   -11.613136
# 115391    -3.110954
# 115392    30.163062
# Name: Corrected_Intensity, dtype: float64
# Cleaned intensity after replacement:
# 115389    -1.934953
# 115390     4.083894
# 115391    10.102741
# 115392    16.121588
# Name: Corrected_Intensity, dtype: float64
# Window start: 720, Window end: 725
# Interpolated values:
# [ -7.27308559  -9.9263992  -12.57971281 -15.23302642 -17.88634003
#  -20.53965365]
# Cleaned Spectrum 115:
#          Wavelength  Corrected_Intensity   Spectrum_ID
# 115710  1705.003906           -16.425969  Spectrum_115
# 115711  1703.941406             2.045301  Spectrum_115
# 115712  1702.878906            -0.707718  Spectrum_115
# 115713  1701.816406            22.423033  Spectrum_115
# 115714  1700.753906           -20.307442  Spectrum_115
#
# Cleaned intensity before replacement:
# 116430    -4.529909
# 116431   -26.912477
# 116432     8.236432
# 116433   -18.247336
# 116434   -20.077727
# 116435   -21.907200
# Name: Corrected_Intensity, dtype: float64
# Cleaned intensity after replacement:
# 116430    -7.273086
# 116431    -9.926399
# 116432   -12.579713
# 116433   -15.233026
# 116434   -17.886340
# 116435   -20.539654
# Name: Corrected_Intensity, dtype: float64
# Window start: 882, Window end: 886
# Interpolated values:
# [ 3.69864075  6.27114038  8.84364    11.41613963 13.98863925]
# Cleaned Spectrum 116:
#          Wavelength  Corrected_Intensity   Spectrum_ID
# 116725  1705.003906            -7.289545  Spectrum_116
# 116726  1703.941406            13.493683  Spectrum_116
# 116727  1702.878906            -3.420110  Spectrum_116
# 116728  1701.816406            -8.559645  Spectrum_116
# 116729  1700.753906           -23.099916  Spectrum_116
#
# Cleaned intensity before replacement:
# 117607     7.674523
# 117608    -0.090037
# 117609    -1.889056
# 117610    36.061535
# 117611     2.461235
# Name: Corrected_Intensity, dtype: float64
# Cleaned intensity after replacement:
# 117607     3.698641
# 117608     6.271140
# 117609     8.843640
# 117610    11.416140
# 117611    13.988639
# Name: Corrected_Intensity, dtype: float64
# Window start: 469, Window end: 472
# Interpolated values:
# [ 18.84848163   5.67130967  -7.50586229 -20.68303425]
# Cleaned Spectrum 117:
#          Wavelength  Corrected_Intensity   Spectrum_ID
# 117740  1705.003906            -9.139556  Spectrum_117
# 117741  1703.941406            14.096295  Spectrum_117
# 117742  1702.878906             9.049879  Spectrum_117
# 117743  1701.816406            25.182211  Spectrum_117
# 117744  1700.753906           -15.136711  Spectrum_117
#
# Cleaned intensity before replacement:
# 118209    30.071115
# 118210   -19.358582
# 118211     8.886020
# 118212   -23.267659
# Name: Corrected_Intensity, dtype: float64
# Cleaned intensity after replacement:
# 118209    18.848482
# 118210     5.671310
# 118211    -7.505862
# 118212   -20.683034
# Name: Corrected_Intensity, dtype: float64
# Window start: 13, Window end: 17
# Interpolated values:
# [ 80.55293883  90.90353979 101.25414074 111.6047417  121.95534266]
# Cleaned Spectrum 118:
#          Wavelength  Corrected_Intensity   Spectrum_ID
# 118755  1705.003906           -47.373690  Spectrum_118
# 118756  1703.941406            -2.886986  Spectrum_118
# 118757  1702.878906           -17.271685  Spectrum_118
# 118758  1701.816406           -24.589837  Spectrum_118
# 118759  1700.753906           -27.197274  Spectrum_118
#
# Cleaned intensity before replacement:
# 118768    -12.874351
# 118769    -53.008497
# 118770    540.719597
# 118771     38.119097
# 118772     -6.685143
# Name: Corrected_Intensity, dtype: float64
# Cleaned intensity after replacement:
# 118768     80.552939
# 118769     90.903540
# 118770    101.254141
# 118771    111.604742
# 118772    121.955343
# Name: Corrected_Intensity, dtype: float64
# Window start: 975, Window end: 977
# Interpolated values:
# [ 6.04128288 14.7600978  23.47891273]
# Cleaned Spectrum 119:
#          Wavelength  Corrected_Intensity   Spectrum_ID
# 119770  1705.003906            12.034164  Spectrum_119
# 119771  1703.941406             9.132999  Spectrum_119
# 119772  1702.878906            -0.868276  Spectrum_119
# 119773  1701.816406            26.781420  Spectrum_119
# 119774  1700.753906           -18.485830  Spectrum_119
#
# Cleaned intensity before replacement:
# 120745    12.212533
# 120746     2.417599
# 120747    29.650162
# Name: Corrected_Intensity, dtype: float64
# Cleaned intensity after replacement:
# 120745     6.041283
# 120746    14.760098
# 120747    23.478913
# Name: Corrected_Intensity, dtype: float64
# Window start: 757, Window end: 758
# Interpolated values:
# [-0.99346124 23.70423386]
# Cleaned Spectrum 120:
#          Wavelength  Corrected_Intensity   Spectrum_ID
# 120785  1705.003906             7.059936  Spectrum_120
# 120786  1703.941406            -9.944939  Spectrum_120
# 120787  1702.878906           -17.570568  Spectrum_120
# 120788  1701.816406            -4.014323  Spectrum_120
# 120789  1700.753906           -53.962551  Spectrum_120
#
# Cleaned intensity before replacement:
# 121542    -0.993461
# 121543    23.704234
# Name: Corrected_Intensity, dtype: float64
# Cleaned intensity after replacement:
# 121542    -0.993461
# 121543    23.704234
# Name: Corrected_Intensity, dtype: float64
# Window start: 892, Window end: 894
# Interpolated values:
# [18.4461432  17.53159068 16.61703817]
# Cleaned Spectrum 121:
#          Wavelength  Corrected_Intensity   Spectrum_ID
# 121800  1705.003906            12.923694  Spectrum_121
# 121801  1703.941406             0.709543  Spectrum_121
# 121802  1702.878906           -16.224576  Spectrum_121
# 121803  1701.816406            -9.622493  Spectrum_121
# 121804  1700.753906             6.390933  Spectrum_121
#
# Cleaned intensity before replacement:
# 122692    27.374622
# 122693    -0.325367
# 122694    25.545517
# Name: Corrected_Intensity, dtype: float64
# Cleaned intensity after replacement:
# 122692    18.446143
# 122693    17.531591
# 122694    16.617038
# Name: Corrected_Intensity, dtype: float64
# Window start: 987, Window end: 989
# Interpolated values:
# [-9.16598368  3.31229438 15.79057243]
# Cleaned Spectrum 122:
#          Wavelength  Corrected_Intensity   Spectrum_ID
# 122815  1705.003906            12.593227  Spectrum_122
# 122816  1703.941406             0.270984  Spectrum_122
# 122817  1702.878906           -14.428713  Spectrum_122
# 122818  1701.816406            20.286344  Spectrum_122
# 122819  1700.753906            -1.453703  Spectrum_122
#
# Cleaned intensity before replacement:
# 123802    -1.067266
# 123803   -12.885141
# 123804    23.889290
# Name: Corrected_Intensity, dtype: float64
# Cleaned intensity after replacement:
# 123802    -9.165984
# 123803     3.312294
# 123804    15.790572
# Name: Corrected_Intensity, dtype: float64
# Window start: 700, Window end: 704
# Interpolated values:
# [ -9.70743834 -10.53553163 -11.36362493 -12.19171823 -13.01981152]
# Cleaned Spectrum 123:
#          Wavelength  Corrected_Intensity   Spectrum_ID
# 123830  1705.003906           -15.027652  Spectrum_123
# 123831  1703.941406            12.706793  Spectrum_123
# 123832  1702.878906             0.388905  Spectrum_123
# 123833  1701.816406            -4.859297  Spectrum_123
# 123834  1700.753906           -17.154106  Spectrum_123
#
# Cleaned intensity before replacement:
# 124530     6.385366
# 124531   -28.484523
# 124532   -28.276969
# 124533    11.110729
# 124534   -17.552727
# Name: Corrected_Intensity, dtype: float64
# Cleaned intensity after replacement:
# 124530    -9.707438
# 124531   -10.535532
# 124532   -11.363625
# 124533   -12.191718
# 124534   -13.019812
# Name: Corrected_Intensity, dtype: float64
# Window start: 565, Window end: 568
# Interpolated values:
# [-5.85956976  1.52594209  8.91145394 16.29696579]
# Cleaned Spectrum 124:
#          Wavelength  Corrected_Intensity   Spectrum_ID
# 124845  1705.003906             0.112371  Spectrum_124
# 124846  1703.941406            -2.709074  Spectrum_124
# 124847  1702.878906            -5.571973  Spectrum_124
# 124848  1701.816406           -10.779714  Spectrum_124
# 124849  1700.753906            -6.570680  Spectrum_124
#
# Cleaned intensity before replacement:
# 125410     1.763449
# 125411    -4.403767
# 125412    -2.098185
# 125413    25.613295
# Name: Corrected_Intensity, dtype: float64
# Cleaned intensity after replacement:
# 125410    -5.859570
# 125411     1.525942
# 125412     8.911454
# 125413    16.296966
# Name: Corrected_Intensity, dtype: float64
# Window start: 638, Window end: 640
# Interpolated values:
# [ 0.49497851 10.06687704 19.63877557]
# Cleaned Spectrum 125:
#          Wavelength  Corrected_Intensity   Spectrum_ID
# 125860  1705.003906            11.092179  Spectrum_125
# 125861  1703.941406             8.235879  Spectrum_125
# 125862  1702.878906            14.749523  Spectrum_125
# 125863  1701.816406           -28.134376  Spectrum_125
# 125864  1700.753906            -7.489762  Spectrum_125
#
# Cleaned intensity before replacement:
# 126498     6.410956
# 126499    -1.765077
# 126500    25.554753
# Name: Corrected_Intensity, dtype: float64
# Cleaned intensity after replacement:
# 126498     0.494979
# 126499    10.066877
# 126500    19.638776
# Name: Corrected_Intensity, dtype: float64
# Window start: 985, Window end: 988
# Interpolated values:
# [ 8.16936372  2.85270965 -2.46394442 -7.78059849]
# Cleaned Spectrum 126:
#          Wavelength  Corrected_Intensity   Spectrum_ID
# 126875  1705.003906           -14.794329  Spectrum_126
# 126876  1703.941406            -3.397524  Spectrum_126
# 126877  1702.878906           -20.276062  Spectrum_126
# 126878  1701.816406           -25.380965  Spectrum_126
# 126879  1700.753906            25.971296  Spectrum_126
#
# Cleaned intensity before replacement:
# 127860     3.696533
# 127861    -2.202584
# 127862    21.065134
# 127863   -21.781553
# Name: Corrected_Intensity, dtype: float64
# Cleaned intensity after replacement:
# 127860    8.169364
# 127861    2.852710
# 127862   -2.463944
# 127863   -7.780598
# Name: Corrected_Intensity, dtype: float64
# Window start: 973, Window end: 976
# Interpolated values:
# [1.57331366 2.6812342  3.78915474 4.89707528]
# Cleaned Spectrum 127:
#          Wavelength  Corrected_Intensity   Spectrum_ID
# 127890  1705.003906            -0.174082  Spectrum_127
# 127891  1703.941406            -2.833503  Spectrum_127
# 127892  1702.878906            15.636458  Spectrum_127
# 127893  1701.816406           -17.649520  Spectrum_127
# 127894  1700.753906           -17.989169  Spectrum_127
#
# Cleaned intensity before replacement:
# 128863     2.352447
# 128864    -9.406575
# 128865    25.627374
# 128866    -5.632468
# Name: Corrected_Intensity, dtype: float64
# Cleaned intensity after replacement:
# 128863    1.573314
# 128864    2.681234
# 128865    3.789155
# 128866    4.897075
# Name: Corrected_Intensity, dtype: float64
# Window start: 839, Window end: 841
# Interpolated values:
# [11.98992529 10.23787321  8.48582113]
# Cleaned Spectrum 128:
#          Wavelength  Corrected_Intensity   Spectrum_ID
# 128905  1705.003906           -14.892456  Spectrum_128
# 128906  1703.941406           -15.365297  Spectrum_128
# 128907  1702.878906           -30.004843  Spectrum_128
# 128908  1701.816406            14.181103  Spectrum_128
# 128909  1700.753906            -0.442762  Spectrum_128
#
# Cleaned intensity before replacement:
# 129744    24.026415
# 129745   -13.835106
# 129746    20.522311
# Name: Corrected_Intensity, dtype: float64
# Cleaned intensity after replacement:
# 129744    11.989925
# 129745    10.237873
# 129746     8.485821
# Name: Corrected_Intensity, dtype: float64
# Window start: 827, Window end: 830
# Interpolated values:
# [14.9815355  16.21380795 17.44608039 18.67835283]
# Cleaned Spectrum 129:
#          Wavelength  Corrected_Intensity   Spectrum_ID
# 129920  1705.003906             3.553293  Spectrum_129
# 129921  1703.941406           -11.094617  Spectrum_129
# 129922  1702.878906             2.447861  Spectrum_129
# 129923  1701.816406            18.346655  Spectrum_129
# 129924  1700.753906            -5.737155  Spectrum_129
#
# Cleaned intensity before replacement:
# 130747    27.046673
# 130748     5.152612
# 130749     3.373059
# 130750    31.747433
# Name: Corrected_Intensity, dtype: float64
# Cleaned intensity after replacement:
# 130747    14.981536
# 130748    16.213808
# 130749    17.446080
# 130750    18.678353
# Name: Corrected_Intensity, dtype: float64
# Window start: 884, Window end: 886
# Interpolated values:
# [-0.55191613  5.58055232 11.71302076]
# Cleaned Spectrum 130:
#          Wavelength  Corrected_Intensity   Spectrum_ID
# 130935  1705.003906           -19.123207  Spectrum_130
# 130936  1703.941406             1.617197  Spectrum_130
# 130937  1702.878906            41.137334  Spectrum_130
# 130938  1701.816406             7.722822  Spectrum_130
# 130939  1700.753906             2.551595  Spectrum_130
#
# Cleaned intensity before replacement:
# 131819    16.009542
# 131820   -27.542365
# 131821    28.274479
# Name: Corrected_Intensity, dtype: float64
# Cleaned intensity after replacement:
# 131819    -0.551916
# 131820     5.580552
# 131821    11.713021
# Name: Corrected_Intensity, dtype: float64
# Window start: 833, Window end: 836
# Interpolated values:
# [12.98735496 13.81878128 14.6502076  15.48163392]
# Cleaned Spectrum 131:
#          Wavelength  Corrected_Intensity   Spectrum_ID
# 131950  1705.003906           -12.569100  Spectrum_131
# 131951  1703.941406            -3.693743  Spectrum_131
# 131952  1702.878906           -41.922917  Spectrum_131
# 131953  1701.816406            18.674448  Spectrum_131
# 131954  1700.753906           -21.880919  Spectrum_131
#
# Cleaned intensity before replacement:
# 132783    23.430990
# 132784     3.574600
# 132785     3.807664
# 132786    26.124723
# Name: Corrected_Intensity, dtype: float64
# Cleaned intensity after replacement:
# 132783    12.987355
# 132784    13.818781
# 132785    14.650208
# 132786    15.481634
# Name: Corrected_Intensity, dtype: float64
# Window start: 682, Window end: 684
# Interpolated values:
# [-10.64488157   6.10942238  22.86372633]
# Cleaned Spectrum 132:
#          Wavelength  Corrected_Intensity   Spectrum_ID
# 132965  1705.003906             1.331695  Spectrum_132
# 132966  1703.941406            19.841551  Spectrum_132
# 132967  1702.878906            -8.752709  Spectrum_132
# 132968  1701.816406             0.308041  Spectrum_132
# 132969  1700.753906           -21.206446  Spectrum_132
#
# Cleaned intensity before replacement:
# 133647    -7.885508
# 133648     0.590676
# 133649    25.623100
# Name: Corrected_Intensity, dtype: float64
# Cleaned intensity after replacement:
# 133647   -10.644882
# 133648     6.109422
# 133649    22.863726
# Name: Corrected_Intensity, dtype: float64
# Window start: 859, Window end: 863
# Interpolated values:
# [-15.59848826  -6.601237     2.39601427  11.39326553  20.39051679]
# Cleaned Spectrum 133:
#          Wavelength  Corrected_Intensity   Spectrum_ID
# 133980  1705.003906             9.766417  Spectrum_133
# 133981  1703.941406           -28.088503  Spectrum_133
# 133982  1702.878906            -2.456309  Spectrum_133
# 133983  1701.816406            13.761757  Spectrum_133
# 133984  1700.753906           -19.414990  Spectrum_133
#
# Cleaned intensity before replacement:
# 134839    -8.409076
# 134840   -18.186481
# 134841    -5.988859
# 134842    34.161095
# 134843    10.403392
# Name: Corrected_Intensity, dtype: float64
# Cleaned intensity after replacement:
# 134839   -15.598488
# 134840    -6.601237
# 134841     2.396014
# 134842    11.393266
# 134843    20.390517
# Name: Corrected_Intensity, dtype: float64
# Window start: 709, Window end: 713
# Interpolated values:
# [-1.95584708  0.72143355  3.39871419  6.07599482  8.75327546]
# Cleaned Spectrum 134:
#          Wavelength  Corrected_Intensity   Spectrum_ID
# 134995  1705.003906            -3.480006  Spectrum_134
# 134996  1703.941406            -1.480975  Spectrum_134
# 134997  1702.878906            26.356740  Spectrum_134
# 134998  1701.816406            -6.974103  Spectrum_134
# 134999  1700.753906            20.867001  Spectrum_134
#
# Cleaned intensity before replacement:
# 135704    15.751236
# 135705    -4.635025
# 135706   -18.836221
# 135707    -4.213092
# 135708    28.926673
# Name: Corrected_Intensity, dtype: float64
# Cleaned intensity after replacement:
# 135704   -1.955847
# 135705    0.721434
# 135706    3.398714
# 135707    6.075995
# 135708    8.753275
# Name: Corrected_Intensity, dtype: float64
# No data for spectrum Spectrum_135
#
# Cleaned spectra saved to /kaggle/working/cleaned_spectra.csv

# %%
# 4) SMOOTHING NOISE BY SAVITZKY-GOLAY FILTER 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.signal import savgol_filter

# Function to apply Savitzky-Golay filter to intensity data
def savgol_filter_intensity(intensity_data, window_size, poly_order):
    smoothed_intensity = savgol_filter(intensity_data, window_size, poly_order)
    return smoothed_intensity

# Read data
cleaned_spectrum_file = '/kaggle/working/cleaned_spectra.csv'
cleaned_data = pd.read_csv(cleaned_spectrum_file)

# Define parameters for Savitzky-Golay filter
window_size = 11  # window size must be odd
poly_order = 3

# Smooth intensity data for each spectrum
smoothed_spectra = []

# Iterate over unique spectrum IDs
for spectrum_id in cleaned_data['Spectrum_ID'].unique():
    spectrum_data = cleaned_data[cleaned_data['Spectrum_ID'] == spectrum_id].copy()

    # Check if spectrum exists in data
    if not spectrum_data.empty:
        # Convert 'Corrected_Intensity' column to numeric
        spectrum_data['Corrected_Intensity'] = pd.to_numeric(spectrum_data['Corrected_Intensity'], errors='coerce')

        # Drop rows with NaN values (if any)
        spectrum_data = spectrum_data.dropna()
        
        print(f"Spectrum ID: {spectrum_id}, Data size after dropping NaNs: {len(spectrum_data)}")

        # Check if window size is smaller than or equal to data size
        if window_size <= len(spectrum_data):
            # Apply Savitzky-Golay filter to smooth intensity data
            smoothed_intensity = savgol_filter_intensity(spectrum_data['Corrected_Intensity'], window_size, poly_order)

            # Create a DataFrame with smoothed intensity data along with spectrum ID & wavelengths
            smoothed_spectrum = pd.DataFrame({
                'Spectrum_ID': spectrum_id,
                'Wavelength': spectrum_data['Wavelength'],
                'Smoothed_Intensity': smoothed_intensity
            })

            # Append smoothed spectrum to the list
            smoothed_spectra.append(smoothed_spectrum)
        else:
            print(f"Window size {window_size} is larger than the size of the data for spectrum ID {spectrum_id}")
    else:
        print(f"No data found for spectrum ID {spectrum_id}")

# Concatenate into a single DataFrame
if smoothed_spectra:
    smoothed_data = pd.concat(smoothed_spectra, ignore_index=True)

    # Save to a CSV file
    smoothed_data_file = '/kaggle/working/smoothed_spectra.csv'
    smoothed_data.to_csv(smoothed_data_file, index=False)
    
    # Confirming successful saving
    print(f"Smoothed spectra saved to {smoothed_data_file}")
    print(smoothed_data.columns)
else:
    print("No spectra were successfully smoothed.")

# Plot
plt.figure(figsize=(16, 10), dpi=150)

for spectrum_id in smoothed_data['Spectrum_ID'].unique():
    spectrum_data = smoothed_data[smoothed_data['Spectrum_ID'] == spectrum_id]
    plt.plot(spectrum_data['Wavelength'], spectrum_data['Smoothed_Intensity'], label=spectrum_id)

plt.title ('Spectral Noise Smoothing')
plt.xlabel('Wavelength')
plt.ylabel('Smoothed Intensity')
plt.grid(True)
plt.show()
# Out:
# Spectrum ID: Spectrum_1, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_2, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_3, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_4, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_5, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_6, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_7, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_8, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_9, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_10, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_11, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_12, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_13, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_14, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_15, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_16, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_17, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_18, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_19, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_20, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_21, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_22, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_23, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_24, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_25, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_26, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_27, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_28, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_29, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_30, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_31, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_32, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_33, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_34, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_35, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_36, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_37, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_38, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_39, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_40, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_41, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_42, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_43, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_44, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_45, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_46, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_47, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_48, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_49, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_50, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_51, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_52, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_53, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_54, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_55, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_56, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_57, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_58, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_59, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_60, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_61, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_62, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_63, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_64, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_65, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_66, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_67, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_68, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_69, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_70, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_71, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_72, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_73, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_74, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_75, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_76, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_77, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_78, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_79, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_80, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_81, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_82, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_83, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_84, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_85, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_86, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_87, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_88, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_89, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_90, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_91, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_92, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_93, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_94, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_95, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_96, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_97, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_98, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_99, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_100, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_101, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_102, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_103, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_104, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_105, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_106, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_107, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_108, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_109, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_110, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_111, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_112, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_113, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_114, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_115, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_116, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_117, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_118, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_119, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_120, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_121, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_122, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_123, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_124, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_125, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_126, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_127, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_128, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_129, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_130, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_131, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_132, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_133, Data size after dropping NaNs: 1015
# Spectrum ID: Spectrum_134, Data size after dropping NaNs: 1015
# Smoothed spectra saved to /kaggle/working/smoothed_spectra.csv
# Index(['Spectrum_ID', 'Wavelength', 'Smoothed_Intensity'], dtype='object')
